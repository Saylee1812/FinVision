# %%
# !pip install pymysql

# %%
import pymysql
cnx=pymysql.connect(
    host="127.0.0.1",
    port=3306,
    user="root",
    password="sqlmy@1812"
)

# %%
query="Select * from bank.banking"

# %%
import pandas as pd
df=pd.read_sql(query,cnx)
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_12284\1331238092.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df=pd.read_sql(query,cnx)

# %%
df.head()
# Out:
#   Client ID             Name  Age  Location ID Joined Bank   Banking Contact  \
# 0  IND81288    Raymond Mills   24        34324  06-05-2019    Anthony Torres
# 1  IND65833    Julia Spencer   23        42205  10-12-2001  Jonathan Hawkins
# 2  IND47499   Stephen Murray   27         7314  25-01-2010     Anthony Berry
# 3  IND72498   Virginia Garza   40        34594  28-03-2019        Steve Diaz
# 4  IND60181  Melissa Sanders   46        41269  20-07-2012        Shawn Long
#
#   Nationality            Occupation Fee Structure Loyalty Classification  ...  \
# 0    American  Safety Technician IV          High                   Jade  ...
# 1     African   Software Consultant          High                   Jade  ...
# 2    European    Help Desk Operator          High                   Gold  ...
# 3    American          Geologist II           Mid                 Silver  ...
# 4    American   Assistant Professor           Mid               Platinum  ...
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Client ID                 3000 non-null   object
#  1   Name                      3000 non-null   object
#  2   Age                       3000 non-null   int64
#  3   Location ID               3000 non-null   int64
#  4   Joined Bank               3000 non-null   object
#  5   Banking Contact           3000 non-null   object
#  6   Nationality               3000 non-null   object
#  7   Occupation                3000 non-null   object
#  8   Fee Structure             3000 non-null   object
#  9   Loyalty Classification    3000 non-null   object
#  10  Estimated Income          3000 non-null   float64
#  11  Superannuation Savings    3000 non-null   float64
#  12  Amount of Credit Cards    3000 non-null   int64
# ...

# %%
df.describe()
# Out:
#                Age   Location ID  Estimated Income  Superannuation Savings  \
# count  3000.000000   3000.000000       3000.000000             3000.000000
# mean     51.039667  21563.323000     171305.034263            25531.599673
# std      19.854760  12462.273017     111935.808209            16259.950770
# min      17.000000     12.000000      15919.480000             1482.030000
# 25%      34.000000  10803.500000      82906.595000            12513.775000
# 50%      51.000000  21129.500000     142313.480000            22357.355000
# 75%      69.000000  32054.500000     242290.305000            35464.740000
# max      85.000000  43369.000000     522330.260000            75963.900000
#
#        Amount of Credit Cards  Credit Card Balance    Bank Loans  \
# count             3000.000000          3000.000000  3.000000e+03
# mean                 1.463667          3176.206943  5.913862e+05
# std                  0.676387          2497.094709  4.575570e+05
# ...

# %%
df.shape
# Out:
# (3000, 25)

# %%
missing_values=df.isnull().sum()
print(missing_values)
# Out:
# Client ID                   0
# Name                        0
# Age                         0
# Location ID                 0
# Joined Bank                 0
# Banking Contact             0
# Nationality                 0
# Occupation                  0
# Fee Structure               0
# Loyalty Classification      0
# Estimated Income            0
# Superannuation Savings      0
# Amount of Credit Cards      0
# Credit Card Balance         0
# Bank Loans                  0
# Bank Deposits               0
# Checking Accounts           0
# Saving Accounts             0
# Foreign Currency Account    0
# Business Lending            0
# Properties Owned            0
# Risk Weighting              0
# BRId                        0
# GenderId                    0
# IAId                        0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

#bar graph for estimated income as income band
bins=[0,100000,300000,float('inf')]
labels=['Low','Mid','High']

df['Income Band']=pd.cut(df['Estimated Income'],bins=bins,labels=labels,right=False)
#count for each band
income_counts=df['Income Band'].value_counts()
#plot graph
plt.figure(figsize=(8,6))
income_counts.plot(kind='bar',color='skyblue')
plt.title('Bar grph for Estimated Income')
plt.xlabel('Category')
plt.ylabel('No.of People')
plt.show()

# %%
#distribution of values in every categorical column
from IPython.display import display
categorical_cols=df[['IAId','BRId','GenderId','Risk Weighting','Properties Owned','Amount of Credit Cards','Occupation','Fee Structure','Loyalty Classification','Nationality','Income Band']].columns

for col in categorical_cols:
    print(f"Value Counts for '{col}': (dtype: {df[col].dtype})")  # show dtype
    display(df[col].value_counts().reset_index().rename(columns={'index': col, col: 'count'}))
    print("\n")
# Out:
# Value Counts for 'IAId': (dtype: int64)
#     count  count
# 0       1    177
# 1       3    177
# 2       4    177
# 3       8    177
# 4       2    177
# 5      11    176
# 6      15    176
# 7      14    176
# 8      13    176
# 9      12    176
# 10     10    176
# 11      9    176
# 12      7     89
# 13      6     89
# 14      5     89
# 15     16     88
# 16     17     88
# 17     18     88
# 18     19     88
# 19     20     88
# 20     21     88
# 21     22     88
# Value Counts for 'BRId': (dtype: int64)
#    count  count
# 0      3   1352
# 1      1    660
# 2      2    495
# 3      4    493
# Value Counts for 'GenderId': (dtype: int64)
#    count  count
# 0      2   1512
# 1      1   1488
# Value Counts for 'Risk Weighting': (dtype: int64)
#    count  count
# 0      2   1222
# 1      1    836
# 2      3    460
# 3      4    322
# 4      5    160
# Value Counts for 'Properties Owned': (dtype: int64)
#    count  count
# 0      2    777
# 1      1    776
# 2      3    742
# ...

# %% [markdown]
# ## UNIVARIATE ANALYSIS OF CATEGORICAL COLUMNS

# %%
#Distribution of categorical columns
for col in categorical_cols:
    if col == 'Occupation':
        continue
    plt.figure(figsize=(8,6))
    sns.histplot(df[col])
    plt.title(f"Distribution of values for {col}")
    plt.xlabel(col)
    plt.ylabel("Count")
    plt.show()

# %% [markdown]
# ## BIVARIATE ANALYSIS OF CATEGORICAL COLUMNS

# %%
for i, col in enumerate(categorical_cols):
    if col=="Occupation":
        continue
    plt.figure(i)
    sns.countplot(data=df,x=col,hue="Nationality")

# %% [markdown]
# ## DISTRIBUTION OF NUMERICAL COLUMNS

# %%
numerical_cols=['Estimated Income','Superannuation Savings','Credit Card Balance','Bank Loans','Bank Deposits','Checking Accounts','Saving Accounts','Foreign Currency Account','Business Lending']

plt.figure(figsize=(15,10))

for i,col in enumerate(numerical_cols):
    plt.subplot(5,3,i+1)
    sns.histplot(df[col],kde=True)
    plt.title(col)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## HEATMAP

# %%
correlation_matrix=df['Estimated Income','Superannuation Savings','Credit Card Balance','Bank Loans','Bank Deposits','Checking Accounts','Saving Accounts','Foreign Currency Account','Business Lending'].corr()

plt.figure(figsize=(12,12))
sns.heatmap(correlation_matrix,annot=True,cmap='crest',fmt='.2f')
plt.title('Correlation Heatmap of Numerical Features',fontsize=16)
plt.show()

# %% [markdown]
# ---
#
# ### 🔹 Key Insights Your Heatmap
#
# 1. **Strong Positive Correlations (close to 1)**
#
#    * **Bank Deposits ↔ Checking Accounts (0.84)**
#    * **Bank Deposits ↔ Saving Accounts (0.75)**
#    * These show that people with more **bank deposits** also tend to have **higher balances in checking and savings accounts**.
#      👉 This makes sense because deposits naturally contribute to these balances.
#
# ---
#
# 2. **Moderately Positive Correlations (0.3 – 0.5)**
#
#    * **Credit Card Balance ↔ Bank Loans (0.37)**
#    * **Credit Card Balance ↔ Foreign Currency Account (0.36)**
#    * **Business Lending ↔ Bank Loans (0.42)**
#    * **Business Lending ↔ Bank Deposits (0.44)**
#      These suggest that customers with **higher credit card usage or loans** may also engage in **foreign currency transactions and business lending**, possibly indicating **higher financial activity or more complex fina
# ncial profiles**.
#
# ---
#
# 3. **Weak Positive Correlations (< 0.3)**
#
#    * **Estimated Income ↔ All other features (0.26 – 0.37)**
#    * Income shows only weak–moderate correlation with savings, loans, deposits, etc.
#      👉 Suggests that higher income does not always translate directly into higher deposits or loans — there are other influencing factors like spending habits or financial goals.
#
# ---
#
# 4. **Low Correlations (near 0)**
#
#    * **Superannuation Savings ↔ other variables (mostly \~0.2)**
#    * Suggests retirement savings are relatively **independent** of day-to-day financial products (like loans, credit cards, or deposits).
#
# ---
#
# ### 🔹 Overall Takeaways
#
# * **Banking products are interconnected**: Deposits, checking, and savings accounts move together strongly.
# * **Income is not a strong predictor** of how much customers save or borrow (weak correlation).
# * **Business lending and bank loans** are moderately related, which makes sense since businesses often take multiple forms of credit.
# * **Superannuation (retirement savings)** stands out as being **independent** from regular fgonals of 1.0) so you have a quick summary?
